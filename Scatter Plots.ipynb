# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1=pd.read_csv('data_2 - Growth Rates.csv')

# %%
df2=pd.read_csv('1980.csv')

# %%
df3=pd.merge(df1,df2,on='Country')

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,7))
sns.regplot(y='Average Rate of growth', x='log(Real GDP per capita)', data=df3, ci=None)
plt.xlabel('log(Real GDP per capita) for 1980')
plt.title('156 Countries',fontsize=17)
# Out:
# Text(0.5, 1.0, '156 Countries')

# %%
df4 = df3[(df3['Country'] == 'Austria')]
df5 = df3[(df3['Country'] == 'Australia')]
df6 = df3[(df3['Country'] == 'Belgium')]
df7 = df3[(df3['Country'] == 'Canada')]
df8= df3[(df3['Country'] == 'Czech Republic')]
df9 = df3[(df3['Country'] == 'Denmark')]
df10= df3[(df3['Country'] == 'Finland')]
df11= df3[(df3['Country'] == 'France')]
df12= df3[(df3['Country'] == 'Germany')]
df13= df3[(df3['Country'] == 'Greece')]
df14= df3[(df3['Country'] == 'Iceland')]
df15= df3[(df3['Country'] == 'Ireland')]
df16= df3[(df3['Country'] == 'Italy')]
df17= df3[(df3['Country'] == 'Japan')]
df18= df3[(df3['Country'] == 'Korea')]
df19= df3[(df3['Country'] == 'Luxembourg')]
df20= df3[(df3['Country'] == 'Netherlands')]
df21= df3[(df3['Country'] == 'Norway')]
df22= df3[(df3['Country'] == 'Portugal')]
df23= df3[(df3['Country'] == 'Spain')]
df24= df3[(df3['Country'] == 'Sweden')]
df25= df3[(df3['Country'] == 'Switzerland')]
df26= df3[(df3['Country'] == 'turkey')]
df27= df3[(df3['Country'] == 'United Kingdom')]
df28= df3[(df3['Country'] == 'United States')]
df29= pd.concat([df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28])
df29
# Out:
#             Country  Average Rate of growth  Year  Population (in millions)  \
# 8           Austria                0.003407  1980                  7.609752
# 7         Australia                0.006203  1980                 14.649114
# 10          Belgium               -0.014739  1980                  9.868995
# 26           Canada                0.007337  1980                 24.537422
# 43          Denmark                0.002457  1980                  5.123945
# 50          Finland                0.004281  1980                  4.788243
# 52           France               -0.007820  1980                 55.357826
# 40          Germany               -0.002299  1980                 78.300652
# 60           Greece               -0.001618  1980                  9.634504
# 72          Iceland                0.000542  1980                  0.228262
# 69          Ireland               -0.000445  1980                  3.434953
# 74            Italy               -0.002803  1980                 56.419277
# 77            Japan               -0.002630  1980                117.827354
# 89       Luxembourg               -0.006018  1980                  0.364038
# 109     Netherlands               -0.007239  1980                 14.148415
# 110          Norway                0.008506  1980                  4.086076
# 119        Portugal               -0.006224  1980                  9.804851
# 48            Spain               -0.014212  1980                 37.796795
# 133          Sweden                0.010498  1980                  8.316338
# 27      Switzerland                0.001735  1980                  6.303610
# 54   United Kingdom                0.002805  1980                 56.265476
# 148   United States                0.009430  1980                229.763046
#
#      Real GDP(in milllion $)  Real GDP per capita  log(Real GDP per capita)
# 8               1.345778e+05          17684.90574                  4.247603
# 7               3.248012e+05          22172.06883                  4.345806
# 10              2.011852e+05          20385.57905                  4.309323
# 26              6.041521e+05          24621.66240                  4.391317
# 43              1.085319e+05          21181.31507                  4.325953
# 50              9.095115e+04          18994.68175                  4.278632
# 52              1.240582e+06          22410.24593                  4.350447
# 40              1.529461e+06          19533.17878                  4.290773
# 60              1.373801e+05          14259.17610                  4.154094
# 72              5.743743e+03          25162.93988                  4.400761
# 69              4.310888e+04          12550.06378                  4.098646
# 74              1.117223e+06          19802.14796                  4.296712
# 77              2.236476e+06          18980.95532                  4.278318
# 89              8.729000e+03          23978.26663                  4.379818
# 109             3.228170e+05          22816.47866                  4.358249
# 110             9.912059e+04          24258.13695                  4.384857
# 119             1.014230e+05          10344.16819                  4.014696
# 48              5.432345e+05          14372.50173                  4.157532
# 133             1.642820e+05          19754.13398                  4.295658
# 27              1.917922e+05          30425.77809                  4.483242
# 54              1.116304e+06          19839.94582                  4.297540
# 148             6.698716e+06          29154.88852                  4.464711

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,7))
sns.regplot(y='Average Rate of growth', x='log(Real GDP per capita)', data=df29, color="g", ci=None)
plt.xlabel('log(Real GDP per capita) for 1980')
plt.title('OECD Countries',fontsize=17)
# Out:
# Text(0.5, 1.0, 'OECD Countries')
