# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df1=pd.read_csv('data_2 - Growth Rates.csv')

# %%
df2=pd.read_csv('1980.csv')

# %%
df3=pd.merge(df1,df2,on='Country')

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,7))
sns.regplot(y='Average Rate of growth', x='log(Real GDP per capita)', data=df3)
plt.xlabel('log(Real GDP per capita) for 1980')
plt.title('156 Countries',fontsize=17)
# Out:
# Text(0.5, 1.0, '156 Countries')

# %%
df4 = df3[(df3['Country'] == 'Austria')]
df5 = df3[(df3['Country'] == 'Australia')]
df5 = df3[(df3['Country'] == 'Belgium')]
df6 = df3[(df3['Country'] == 'Canada')]
df7 = df3[(df3['Country'] == 'Chile')]
df8 = df3[(df3['Country'] == 'Colombia')]
df9= df3[(df3['Country'] == 'Czech Republic')]
df10 = df3[(df3['Country'] == 'Denmark')]
df11= df3[(df3['Country'] == 'Estonia')]
df12= df3[(df3['Country'] == 'Finland')]
df13= df3[(df3['Country'] == 'France')]
df14= df3[(df3['Country'] == 'Germany')]
df15= df3[(df3['Country'] == 'Greece')]
df16= df3[(df3['Country'] == 'Hungary')]
df17= df3[(df3['Country'] == 'Iceland')]
df18= df3[(df3['Country'] == 'Ireland')]
df19= df3[(df3['Country'] == 'Italy')]
df20= df3[(df3['Country'] == 'Israel')]
df21= df3[(df3['Country'] == 'Japan')]
df22= df3[(df3['Country'] == 'Korea')]
df23= df3[(df3['Country'] == 'Latvia')]
df24= df3[(df3['Country'] == 'Lithuania')]
df25= df3[(df3['Country'] == 'Luxembourg')]
df26= df3[(df3['Country'] == 'Mexico')]
df27= df3[(df3['Country'] == 'Netherlands')]
df28= df3[(df3['Country'] == 'Norway')]
df29= df3[(df3['Country'] == 'Poland')]
df30= df3[(df3['Country'] == 'Portugal')]
df31= df3[(df3['Country'] == 'Slovak Republic')]
df32= df3[(df3['Country'] == 'Slovenia')]
df33= df3[(df3['Country'] == 'Spain')]
df34= df3[(df3['Country'] == 'Sweden')]
df35= df3[(df3['Country'] == 'Switzerland')]
df36= df3[(df3['Country'] == 'turkey')]
df37= df3[(df3['Country'] == 'United Kingdom')]
df38= df3[(df3['Country'] == 'United States')]
df39= df3[(df3['Country'] == 'United Arab Emirates')]
df39= df3[(df3['Country'] == 'Kuwait')]
df40= df3[(df3['Country'] == 'Qatar')]
df41= pd.concat([df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40])
df41
# Out:
#             Country  Average Rate of growth  Year  Population (in millions)  \
# 8           Austria                0.003407  1980                  7.609752
# 10          Belgium               -0.014739  1980                  9.868995
# 26           Canada                0.007337  1980                 24.537422
# 28            Chile               -0.014243  1980                 11.266226
# 34         Colombia               -0.007639  1980                 27.737900
# 43          Denmark                0.002457  1980                  5.123945
# 50          Finland                0.004281  1980                  4.788243
# 52           France               -0.007820  1980                 55.357826
# 40          Germany               -0.002299  1980                 78.300652
# 60           Greece               -0.001618  1980                  9.634504
# 66          Hungary                0.002164  1980                 10.754766
# ...

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(8,7))
sns.regplot(y='Average Rate of growth', x='log(Real GDP per capita)', data=df41, color="g")
plt.xlabel('log(Real GDP per capita) for 1980')
plt.title('OECD Countries',fontsize=17)
# Out:
# Text(0.5, 1.0, 'OECD Countries')
