# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("data_3 - growth (1).csv")

# %%
df.head()
# Out:
#      country     rate of growth of real gdp  \
# 0        NaN  (Y(1985)-Y(1980))/(5*Y(1980))
# 1  Argentina                  0.03848047821
# 2  Australia                  0.03064942522
# 3    Austria                 0.008141622594
# 4    Belgium                 -0.03040171869
#
#    1/3*(K(1985)-K(1980))/(5*K(1980))  1/3*(K(1985)-K(1980))/(5*K(1980)).1  \
# 0                                NaN                                  NaN
# 1                           0.005429                             0.016286
# 2                           0.013310                             0.039931
# 3                           0.009364                             0.028091
# 4                           0.003398                             0.010195
#
#    2/3*(N(1985)-N(1980))/(5*N(1980))  rate of growth of N  Solow Residual  \
# 0                                NaN                  NaN             NaN
# 1                           0.006227             0.009340        0.026825
# ...

# %%
df = df[1:]

# %%
df.head()
# Out:
#       country rate of growth of real gdp  1/3*(K(1985)-K(1980))/(5*K(1980))  \
# 1   Argentina              0.03848047821                           0.005429
# 2   Australia              0.03064942522                           0.013310
# 3     Austria             0.008141622594                           0.009364
# 4     Belgium             -0.03040171869                           0.003398
# 5  Bangladesh              0.03812464241                           0.023207
#
#    1/3*(K(1985)-K(1980))/(5*K(1980)).1  2/3*(N(1985)-N(1980))/(5*N(1980))  \
# 1                             0.016286                           0.006227
# 2                             0.039931                           0.006188
# 3                             0.028091                          -0.004131
# 4                             0.010195                           0.000518
# 5                             0.069620                           0.020129
#
# ...

# %%
plt.grid()
P=sns.FacetGrid(data=df,height=6,aspect=1.5, legend_out=True, palette="Set1").map(sns.kdeplot, "Solow Residual")
plt.ylabel('Density',fontsize=15)
plt.xlabel('Solow Residual',fontsize=15)
plt.legend()

# %%
plt.grid()
P=sns.FacetGrid(data=df,height=6,aspect=2, legend_out=True).map(sns.kdeplot, "Solow Residual", color='#c0504d')
sns.set(rc={'axes.facecolor':'#27272d', 'figure.facecolor':'#27272d'})

COLOR = 'white'
mpl.rcParams['text.color'] = COLOR
mpl.rcParams['axes.labelcolor'] = COLOR
mpl.rcParams['xtick.color'] = COLOR
mpl.rcParams['ytick.color'] = COLOR

plt.ylabel('Density',fontsize=15, color='w')
plt.xlabel('Solow Residual',fontsize=15, color='w')
#plt.title('Kernel density plot of Solow Residual',fontsize=23, fontweight="bold")
mean=df['Solow Residual'].mean()
median=df['Solow Residual'].median()
mode= 0.01111111111
plt.axvline(mean, color='#f79646', linestyle='--', label='Mean')
plt.axvline(median, color='#4f81bd', linestyle='--', label='Median')
plt.axvline(mode, color='#9bbb59', linestyle='--', label='Mode')
plt.legend(fontsize= 'x-large') 
plt.grid(True, linewidth=0.5, color='w', linestyle='-')
plt.show()
#plt.style.use(color = "#27272d")
#plt.grid(True, linewidth=0.5, color='#27272d', linestyle='-')
